# %% [markdown]
# <a href="https://colab.research.google.com/github/harshTheAnalyst/Python-Learning-Journey/blob/main/Data_er_day3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
a=int(input("enter value for a : "))
b=int(input("enter value for b : "))
print(a+b)
print(a-b)
print(a/b)
print(a//b)
print(a*b)
print(a%b)
print(a**b)
# Out:
# enter value for a : 20
# enter value for b : 3
# 23
# 17
# 6.666666666666667
# 6
# 60
# 2
# 8000

# %%
a=int(input("enter value for a : "))
b=int(input("enter value for b : "))
print(a==b)
print(a!=b)
print(a<b)
print(a>b)
# Out:
# enter value for a : 5
# enter value for b : 8
# False
# True
# True
# False

# %%
sal=50000
sal+=5500
print(sal)
sal-=1700
print(sal)
# Out:
# 55500
# 53800

# %%
#salary program

name=input("enter name of employee ")
sal=int(input("enter salary "))
yearly=sal*12
bonus= yearly*10/100
print(f"employee_name {name}\nemployee monthly salary {sal}\nyearly salary is {yearly}\nbonus is {bonus}\n bonus_yearly_salary {bonus+yearly}")
# Out:
# enter name of employee Harsh kumar
# enter salary 500000
# employee_name Harsh kumar
# employee monthly salary 500000
# yearly salary is 6000000
# bonus is 600000.0
#  bonus_yearly_salary 6600000.0
