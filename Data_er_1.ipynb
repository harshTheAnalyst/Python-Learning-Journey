# %% [markdown]
# <a href="https://colab.research.google.com/github/harshTheAnalyst/Python-Learning-Journey/blob/main/Data_er_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("hello harsh welcome !")
# Out:
# hello harsh welcome !

# %%
import pandas as pd
import numpy as np
print(pd.__version__)
# Out:
# 2.2.2

# %%
Var1='harsh'
Age= 32
print(Age, Var1)
# Out:
# 32 harsh
