# %% [markdown]
# <a href="https://colab.research.google.com/github/harshTheAnalyst/Python-Learning-Journey/blob/main/Data_er_day2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name=input("enter your name ")
age=int(input("enter your age "))
height=float(input("enter your height in ft "))
country=input("enter your dream country ")

print(f"my name is {name} and age is {age}\n my dream country is {country} \n my height in ft is {height}")

print(type(name))
print(type(age))
print(type(height))
# Out:
# enter your name Harsh kumar
# enter your age 31
# enter your height in ft 6.0
# enter your dream country New zealand
# my name is Harsh kumar and age is 31
#  my dream country is New zealand
#  my height in ft is 6.0
# <class 'str'>
# <class 'int'>
# <class 'float'>

# %%
name = input("Enter your name: ")
age = int(input("Enter your age: "))

print(f"My name is {name} and age is {age}")
print(type(name))
print(type(age))
# Out:
# Enter your name: Harsh
# Enter your age: 32
# My name is Harsh and age is 32
# <class 'str'>
# <class 'int'>
